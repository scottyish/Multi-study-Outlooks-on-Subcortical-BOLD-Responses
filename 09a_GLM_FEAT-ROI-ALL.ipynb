# %% [markdown]
# # FSL FEAT nipype

# %%
import os
import glob

import nipype
import nipype.interfaces.io as nio
import nipype.interfaces.fsl as fsl
import nipype.interfaces.ants as ants
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.algorithms.modelgen as model

# %%
# # general set-up
base_dir = '/home/scotti/projects/3t_7t_sst_comparison'
work_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders')
# roi_hp_dir = os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', this_dataset)

hpcutoff = 10000.   # in seconds
model_n = [0]
spaces = ['MNI152NLin2009cAsym']   # shouldn't touch this but just in case we _do_ want to go back to MNI....

# %% [markdown]
# ## pipeline setup

# %%
import re
all_fns = sorted(glob.glob(os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', '*', 'sub-*', 'func',  f'sub-*_task-*_run-*_space-*_desc-preproc_bold.nii.gz')))
regex = re.compile('.*fsl_feat_roi_func/(?P<dataset>\S+)/sub-.*/func/sub-(?P<subject>\S+)_task-.*_run-(?P<run>\d)_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz')
ds_subs = [regex.match(x).groupdict()['dataset'] + '-' + regex.match(x).groupdict()['subject'] for x in all_fns]

import numpy as np
all_subs = np.unique(ds_subs).tolist()    #### for testing only

# %%
datasets = ['Leipzig_7T_SM', 'Leipzig_7T_GdH', 'openfmri_3T', 'aron_3T', 'NTNU_7T_SJSI']
all_subject_ids = [x.split('-')[-1] for x in all_subs]
# all_subject_ids

# %% [markdown]
# # first & second level models

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
    confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.1  # stick functions. Set to 0.1 so we know baseline-to-max value (0.0211 as per Jeanette Mumford)
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

    ### confounds ###
    confounds = pd.read_csv(confounds_fn, sep='\t')
#        cosine_cols = [x for x in confounds.columns if 'cos' in x]
    include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
    confounds = confounds[include_confounds].fillna(method='bfill')

    # get retroicor
    if include_physio:
        ## take first 20 aCompCor components
#         print("No retroicor found, including 20 a_comp_cor components")
        # not all subjects have 20 compcor components, so filter
        a_comp_cor = pd.read_csv(confounds_fn, sep='\t')
        if num_acopm:=len([col for col in a_comp_cor.columns if 'a_comp_cor_' in col]) < 20:
            a_comp_cor = a_comp_cor[['a_comp_cor_' + str(x).zfill(2) for x in range(num_acopm)]]
        else: # use normal 20
            a_comp_cor[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]

    # save the confounds that we actually include in the GLM to csv, no header or index
    confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
    os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
    confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1])
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_dataset_sub(ds_sub):
    ds,sub = ds_sub.split('-')
    return ds, sub
    
def get_tr(dataset):
    if dataset=='Leipzig_7T_SM':
        t_r=3
    elif dataset=='NTNU_7T_SJSI':
        t_r=1.38
    else:
        t_r=2
    return t_r, -t_r/2

def get_task(dataset):
    if dataset=='Leipzig_7T_SM':
        task = 'stop'
    elif dataset=='Leipzig_7T_GdH':
        task='stop'
    elif dataset=='NTNU_7T_SJSI':
        task='sst'
    elif dataset=='openfmri_3T':
        task='stopsignal'
    elif dataset=='aron_3T':
        task='stopsignal'
    return task

def get_runs_per_sub(dataset, subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if dataset == 'aron_3T':
        if not subject_id in ['11','12']:
            runs = [1,2,3]
        else:
            runs = [1,2]
    elif dataset == 'openfmri_3T':
        runs = [1]
    elif dataset == 'Leipzig_7T_SM':
        if not subject_id in ['17']:
            runs = [1,2,3]
        else:
            runs = [1,2]
    elif dataset == 'Leipzig_7T_GdH':
        if not subject_id in ['DA9T']:
            runs = [1,2,3]
        else:
            runs = [1,2]
    elif dataset == 'NTNU_7T_SJSI':
        if not subject_id in ['040']:
            runs = [1,2]
        else:
            runs = [1]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_roi')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', 'all_datasets')
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['ds_sub', 'space', 'model_n']), name='identity')
identity.iterables = [('ds_sub', all_subs),
                      ('space', spaces),
                      ('model_n', model_n)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'roi_funcs': os.path.join(base_dir, 'derivatives', 'fsl_feat_roi_func', '{dataset}',
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{{task}}_run-*_space-{{space}}*_desc-preproc_bold.nii.gz'),
            }


ds_sub_getter = pe.Node(util.Function(function=get_dataset_sub,
                                        input_names=['ds_sub'],
                                        output_names=['dataset', 'subject_id']),
                         name='ds_sub_getter')
task_getter = pe.Node(util.Function(function=get_task,
                                        input_names=['dataset'],
                                        output_names=['task']),
                         name='task_getter')
tr_getter = pe.Node(util.Function(function=get_tr,
                                        input_names=['dataset'],
                                        output_names=['t_r', 'shift']),
                         name='tr_getter')


selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'ds_sub', ds_sub_getter, 'ds_sub')

#workflow.connect(identity, 'dataset', subject_getter, 'ds')
workflow.connect(ds_sub_getter, 'subject_id', selector, 'subject_id')
workflow.connect(ds_sub_getter, 'dataset', selector, 'dataset')
workflow.connect(ds_sub_getter, 'dataset', task_getter, 'dataset')
workflow.connect(task_getter, 'task', selector, 'task')
workflow.connect(identity, 'space', selector, 'space')
workflow.connect(ds_sub_getter, 'dataset', tr_getter, 'dataset')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['dataset', 'subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(ds_sub_getter, 'subject_id', run_info_getter, 'subject_id')
workflow.connect(ds_sub_getter, 'dataset', run_info_getter, 'dataset')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'], 
                                 name='session_info_getter')
workflow.connect(task_getter, 'task', session_info_getter, 'task')
workflow.connect(ds_sub_getter, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(tr_getter, 'shift', session_info_getter, 'shift')
#session_info_getter.inputs.task=task
#session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='MNI152NLin2009cAsym'
#session_info_getter.inputs.shift = -t_r/2

workflow.connect(ds_sub_getter, 'dataset', session_info_getter, 'this_dataset')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
#specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff
workflow.connect(tr_getter, 't_r', specifymodel, 'time_repetition')


workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'roi_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
# level1design.inputs.interscan_interval = t_r
workflow.connect(tr_getter, 't_r', level1design, 'interscan_interval')
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=False, # prewhitening yes or no?
#                                                  autocorr_noestimate=True,
                                                 mask_size = 0,
#                                                 threshold = 100),  # threshold for signal, default = 1000 but will lose data that way as 1000 is higher than alot of the voxel signals
                                                 threshold = 50),  # SM: set threshold of signal to 50; background is 0, and units are PSC with mean 100
                                                 name='modelestimate',
                                                 iterfield=iterfield,
                                                 mem_gb=10,
                                                 full_data = True,
                                                 output_pwdata=True)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'roi_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0] if isinstance(x, list) else x
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])
flameo.inputs.mask_file='/home/scotti/projects/3t_7t_sst_comparison/derivatives/mni3mm_brain_mask.nii.gz'

workflow.connect([
    # (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_sst_roi')

substitutions = [(f'mni/level2_{stat_type}s/_ds_sub_{this_dataset}-{sub}_model_n_{model_n_}_space_MNI152NLin2009cAsym/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/model-{model_n_}/sub-{sub}_task-sst_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in all_subject_ids
                  for this_dataset in datasets
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]

ds.inputs.substitutions = substitutions

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.mni.level2_tdof_ts')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs': 20, 'memory_gb': 200})
# Out:
# 240713-13:39:39,267 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_roi settings: ['check', 'execution', 'logging', 'monitoring']
# 240713-13:40:09,69 nipype.workflow INFO:
# 	 Running in parallel.
# 240713-13:40:09,90 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 174 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:09,381 nipype.workflow INFO:
# 	 [Job 0] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,383 nipype.workflow INFO:
# 	 [Job 1] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,385 nipype.workflow INFO:
# 	 [Job 2] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,386 nipype.workflow INFO:
# 	 [Job 3] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,387 nipype.workflow INFO:
# 	 [Job 4] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,389 nipype.workflow INFO:
# 	 [Job 5] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,390 nipype.workflow INFO:
# 	 [Job 6] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,391 nipype.workflow INFO:
# 	 [Job 7] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,393 nipype.workflow INFO:
# 	 [Job 8] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,394 nipype.workflow INFO:
# 	 [Job 9] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,395 nipype.workflow INFO:
# 	 [Job 10] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,397 nipype.workflow INFO:
# 	 [Job 11] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,398 nipype.workflow INFO:
# 	 [Job 12] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,399 nipype.workflow INFO:
# 	 [Job 13] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,405 nipype.workflow INFO:
# 	 [Job 14] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,406 nipype.workflow INFO:
# 	 [Job 15] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,408 nipype.workflow INFO:
# 	 [Job 16] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,409 nipype.workflow INFO:
# 	 [Job 17] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,410 nipype.workflow INFO:
# 	 [Job 18] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:09,412 nipype.workflow INFO:
# 	 [Job 19] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,93 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 214 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:11,329 nipype.workflow INFO:
# 	 [Job 20] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,331 nipype.workflow INFO:
# 	 [Job 21] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,333 nipype.workflow INFO:
# 	 [Job 22] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,334 nipype.workflow INFO:
# 	 [Job 23] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,335 nipype.workflow INFO:
# 	 [Job 24] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,337 nipype.workflow INFO:
# 	 [Job 25] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,338 nipype.workflow INFO:
# 	 [Job 26] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,339 nipype.workflow INFO:
# 	 [Job 27] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,341 nipype.workflow INFO:
# 	 [Job 28] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,342 nipype.workflow INFO:
# 	 [Job 29] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,343 nipype.workflow INFO:
# 	 [Job 30] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,345 nipype.workflow INFO:
# 	 [Job 31] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,346 nipype.workflow INFO:
# 	 [Job 32] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,347 nipype.workflow INFO:
# 	 [Job 33] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,349 nipype.workflow INFO:
# 	 [Job 34] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,350 nipype.workflow INFO:
# 	 [Job 35] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,351 nipype.workflow INFO:
# 	 [Job 36] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,353 nipype.workflow INFO:
# 	 [Job 37] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,354 nipype.workflow INFO:
# 	 [Job 38] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:11,355 nipype.workflow INFO:
# 	 [Job 39] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,94 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 254 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:13,298 nipype.workflow INFO:
# 	 [Job 40] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,300 nipype.workflow INFO:
# 	 [Job 41] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,302 nipype.workflow INFO:
# 	 [Job 42] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,303 nipype.workflow INFO:
# 	 [Job 43] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,304 nipype.workflow INFO:
# 	 [Job 44] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,306 nipype.workflow INFO:
# 	 [Job 45] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,307 nipype.workflow INFO:
# 	 [Job 46] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,308 nipype.workflow INFO:
# 	 [Job 47] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,310 nipype.workflow INFO:
# 	 [Job 48] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,311 nipype.workflow INFO:
# 	 [Job 49] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,313 nipype.workflow INFO:
# 	 [Job 50] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,314 nipype.workflow INFO:
# 	 [Job 51] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,315 nipype.workflow INFO:
# 	 [Job 52] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,317 nipype.workflow INFO:
# 	 [Job 53] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,318 nipype.workflow INFO:
# 	 [Job 54] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,319 nipype.workflow INFO:
# 	 [Job 55] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,321 nipype.workflow INFO:
# 	 [Job 56] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,322 nipype.workflow INFO:
# 	 [Job 57] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,323 nipype.workflow INFO:
# 	 [Job 58] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:13,325 nipype.workflow INFO:
# 	 [Job 59] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,96 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 294 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:15,299 nipype.workflow INFO:
# 	 [Job 60] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,301 nipype.workflow INFO:
# 	 [Job 61] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,303 nipype.workflow INFO:
# 	 [Job 62] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,304 nipype.workflow INFO:
# 	 [Job 63] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,305 nipype.workflow INFO:
# 	 [Job 64] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,307 nipype.workflow INFO:
# 	 [Job 65] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,308 nipype.workflow INFO:
# 	 [Job 66] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,309 nipype.workflow INFO:
# 	 [Job 67] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,311 nipype.workflow INFO:
# 	 [Job 68] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,312 nipype.workflow INFO:
# 	 [Job 69] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,313 nipype.workflow INFO:
# 	 [Job 70] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,315 nipype.workflow INFO:
# 	 [Job 71] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,316 nipype.workflow INFO:
# 	 [Job 72] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,317 nipype.workflow INFO:
# 	 [Job 73] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,319 nipype.workflow INFO:
# 	 [Job 74] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,320 nipype.workflow INFO:
# 	 [Job 75] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,321 nipype.workflow INFO:
# 	 [Job 76] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,323 nipype.workflow INFO:
# 	 [Job 77] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,324 nipype.workflow INFO:
# 	 [Job 78] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:15,325 nipype.workflow INFO:
# 	 [Job 79] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,97 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 334 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:17,301 nipype.workflow INFO:
# 	 [Job 80] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,303 nipype.workflow INFO:
# 	 [Job 81] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,304 nipype.workflow INFO:
# 	 [Job 82] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,306 nipype.workflow INFO:
# 	 [Job 83] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,307 nipype.workflow INFO:
# 	 [Job 84] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,313 nipype.workflow INFO:
# 	 [Job 85] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,314 nipype.workflow INFO:
# 	 [Job 86] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,316 nipype.workflow INFO:
# 	 [Job 87] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,317 nipype.workflow INFO:
# 	 [Job 88] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,319 nipype.workflow INFO:
# 	 [Job 89] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,320 nipype.workflow INFO:
# 	 [Job 90] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,322 nipype.workflow INFO:
# 	 [Job 91] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,323 nipype.workflow INFO:
# 	 [Job 92] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,325 nipype.workflow INFO:
# 	 [Job 93] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,326 nipype.workflow INFO:
# 	 [Job 94] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,328 nipype.workflow INFO:
# 	 [Job 95] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,329 nipype.workflow INFO:
# 	 [Job 96] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,331 nipype.workflow INFO:
# 	 [Job 97] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,332 nipype.workflow INFO:
# 	 [Job 98] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:17,333 nipype.workflow INFO:
# 	 [Job 99] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,99 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 374 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:19,340 nipype.workflow INFO:
# 	 [Job 100] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,343 nipype.workflow INFO:
# 	 [Job 101] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,344 nipype.workflow INFO:
# 	 [Job 102] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,346 nipype.workflow INFO:
# 	 [Job 103] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,347 nipype.workflow INFO:
# 	 [Job 104] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,349 nipype.workflow INFO:
# 	 [Job 105] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,350 nipype.workflow INFO:
# 	 [Job 106] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,352 nipype.workflow INFO:
# 	 [Job 107] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,353 nipype.workflow INFO:
# 	 [Job 108] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,354 nipype.workflow INFO:
# 	 [Job 109] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,356 nipype.workflow INFO:
# 	 [Job 110] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,357 nipype.workflow INFO:
# 	 [Job 111] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,359 nipype.workflow INFO:
# 	 [Job 112] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,360 nipype.workflow INFO:
# 	 [Job 113] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,362 nipype.workflow INFO:
# 	 [Job 114] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,363 nipype.workflow INFO:
# 	 [Job 115] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,364 nipype.workflow INFO:
# 	 [Job 116] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,366 nipype.workflow INFO:
# 	 [Job 117] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,367 nipype.workflow INFO:
# 	 [Job 118] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:19,369 nipype.workflow INFO:
# 	 [Job 119] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,101 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 414 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:21,303 nipype.workflow INFO:
# 	 [Job 120] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,305 nipype.workflow INFO:
# 	 [Job 121] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,307 nipype.workflow INFO:
# 	 [Job 122] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,308 nipype.workflow INFO:
# 	 [Job 123] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,310 nipype.workflow INFO:
# 	 [Job 124] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,311 nipype.workflow INFO:
# 	 [Job 125] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,312 nipype.workflow INFO:
# 	 [Job 126] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,314 nipype.workflow INFO:
# 	 [Job 127] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,315 nipype.workflow INFO:
# 	 [Job 128] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,317 nipype.workflow INFO:
# 	 [Job 129] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,318 nipype.workflow INFO:
# 	 [Job 130] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,320 nipype.workflow INFO:
# 	 [Job 131] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,321 nipype.workflow INFO:
# 	 [Job 132] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,323 nipype.workflow INFO:
# 	 [Job 133] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,324 nipype.workflow INFO:
# 	 [Job 134] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,326 nipype.workflow INFO:
# 	 [Job 135] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,327 nipype.workflow INFO:
# 	 [Job 136] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,329 nipype.workflow INFO:
# 	 [Job 137] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,330 nipype.workflow INFO:
# 	 [Job 138] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:21,331 nipype.workflow INFO:
# 	 [Job 139] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,103 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 454 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:23,309 nipype.workflow INFO:
# 	 [Job 140] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,311 nipype.workflow INFO:
# 	 [Job 141] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,313 nipype.workflow INFO:
# 	 [Job 142] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,314 nipype.workflow INFO:
# 	 [Job 143] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,316 nipype.workflow INFO:
# 	 [Job 144] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,317 nipype.workflow INFO:
# 	 [Job 145] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,318 nipype.workflow INFO:
# 	 [Job 146] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,320 nipype.workflow INFO:
# 	 [Job 147] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,321 nipype.workflow INFO:
# 	 [Job 148] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,323 nipype.workflow INFO:
# 	 [Job 149] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,324 nipype.workflow INFO:
# 	 [Job 150] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,326 nipype.workflow INFO:
# 	 [Job 151] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,327 nipype.workflow INFO:
# 	 [Job 152] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,329 nipype.workflow INFO:
# 	 [Job 153] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,330 nipype.workflow INFO:
# 	 [Job 154] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,332 nipype.workflow INFO:
# 	 [Job 155] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,333 nipype.workflow INFO:
# 	 [Job 156] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,334 nipype.workflow INFO:
# 	 [Job 157] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,336 nipype.workflow INFO:
# 	 [Job 158] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:23,337 nipype.workflow INFO:
# 	 [Job 159] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,105 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 494 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:25,308 nipype.workflow INFO:
# 	 [Job 160] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,310 nipype.workflow INFO:
# 	 [Job 161] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,312 nipype.workflow INFO:
# 	 [Job 162] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,313 nipype.workflow INFO:
# 	 [Job 163] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,315 nipype.workflow INFO:
# 	 [Job 164] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,316 nipype.workflow INFO:
# 	 [Job 165] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,318 nipype.workflow INFO:
# 	 [Job 166] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,319 nipype.workflow INFO:
# 	 [Job 167] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,321 nipype.workflow INFO:
# 	 [Job 168] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,322 nipype.workflow INFO:
# 	 [Job 169] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,323 nipype.workflow INFO:
# 	 [Job 170] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,325 nipype.workflow INFO:
# 	 [Job 171] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,326 nipype.workflow INFO:
# 	 [Job 172] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,328 nipype.workflow INFO:
# 	 [Job 173] Cached (feat_level12_sst_roi.ds_sub_getter).
# 240713-13:40:25,330 nipype.workflow INFO:
# 	 [Job 174] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:25,332 nipype.workflow INFO:
# 	 [Job 175] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:25,334 nipype.workflow INFO:
# 	 [Job 176] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:25,335 nipype.workflow INFO:
# 	 [Job 177] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:25,337 nipype.workflow INFO:
# 	 [Job 178] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:25,339 nipype.workflow INFO:
# 	 [Job 179] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,107 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 520 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:27,313 nipype.workflow INFO:
# 	 [Job 180] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,315 nipype.workflow INFO:
# 	 [Job 181] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,317 nipype.workflow INFO:
# 	 [Job 182] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,319 nipype.workflow INFO:
# 	 [Job 183] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,321 nipype.workflow INFO:
# 	 [Job 184] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,323 nipype.workflow INFO:
# 	 [Job 185] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,324 nipype.workflow INFO:
# 	 [Job 186] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,326 nipype.workflow INFO:
# 	 [Job 187] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,328 nipype.workflow INFO:
# 	 [Job 188] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,330 nipype.workflow INFO:
# 	 [Job 189] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,332 nipype.workflow INFO:
# 	 [Job 190] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,333 nipype.workflow INFO:
# 	 [Job 191] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,335 nipype.workflow INFO:
# 	 [Job 192] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,337 nipype.workflow INFO:
# 	 [Job 193] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,339 nipype.workflow INFO:
# 	 [Job 194] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,341 nipype.workflow INFO:
# 	 [Job 195] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,342 nipype.workflow INFO:
# 	 [Job 196] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:27,344 nipype.workflow INFO:
# 	 [Job 197] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:27,346 nipype.workflow INFO:
# 	 [Job 198] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:27,348 nipype.workflow INFO:
# 	 [Job 199] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,109 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 517 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:29,314 nipype.workflow INFO:
# 	 [Job 200] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,316 nipype.workflow INFO:
# 	 [Job 201] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,319 nipype.workflow INFO:
# 	 [Job 202] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,320 nipype.workflow INFO:
# 	 [Job 203] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,322 nipype.workflow INFO:
# 	 [Job 204] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,324 nipype.workflow INFO:
# 	 [Job 205] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,326 nipype.workflow INFO:
# 	 [Job 206] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,327 nipype.workflow INFO:
# 	 [Job 207] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,329 nipype.workflow INFO:
# 	 [Job 208] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,331 nipype.workflow INFO:
# 	 [Job 209] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,333 nipype.workflow INFO:
# 	 [Job 210] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,334 nipype.workflow INFO:
# 	 [Job 211] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,336 nipype.workflow INFO:
# 	 [Job 212] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,338 nipype.workflow INFO:
# 	 [Job 213] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,340 nipype.workflow INFO:
# 	 [Job 214] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,341 nipype.workflow INFO:
# 	 [Job 215] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,343 nipype.workflow INFO:
# 	 [Job 216] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:29,345 nipype.workflow INFO:
# 	 [Job 217] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:29,347 nipype.workflow INFO:
# 	 [Job 218] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:29,348 nipype.workflow INFO:
# 	 [Job 219] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,111 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 523 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:31,357 nipype.workflow INFO:
# 	 [Job 220] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,360 nipype.workflow INFO:
# 	 [Job 221] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,362 nipype.workflow INFO:
# 	 [Job 222] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,364 nipype.workflow INFO:
# 	 [Job 223] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,366 nipype.workflow INFO:
# 	 [Job 224] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,367 nipype.workflow INFO:
# 	 [Job 225] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,369 nipype.workflow INFO:
# 	 [Job 226] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,371 nipype.workflow INFO:
# 	 [Job 227] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,373 nipype.workflow INFO:
# 	 [Job 228] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,375 nipype.workflow INFO:
# 	 [Job 229] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,376 nipype.workflow INFO:
# 	 [Job 230] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,378 nipype.workflow INFO:
# 	 [Job 231] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,380 nipype.workflow INFO:
# 	 [Job 232] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,382 nipype.workflow INFO:
# 	 [Job 233] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,383 nipype.workflow INFO:
# 	 [Job 234] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,385 nipype.workflow INFO:
# 	 [Job 235] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,387 nipype.workflow INFO:
# 	 [Job 236] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:31,389 nipype.workflow INFO:
# 	 [Job 237] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:31,390 nipype.workflow INFO:
# 	 [Job 238] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:31,392 nipype.workflow INFO:
# 	 [Job 239] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,316 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 530 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:33,515 nipype.workflow INFO:
# 	 [Job 240] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,518 nipype.workflow INFO:
# 	 [Job 241] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,520 nipype.workflow INFO:
# 	 [Job 242] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,521 nipype.workflow INFO:
# 	 [Job 243] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,523 nipype.workflow INFO:
# 	 [Job 244] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,525 nipype.workflow INFO:
# 	 [Job 245] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,527 nipype.workflow INFO:
# 	 [Job 246] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,528 nipype.workflow INFO:
# 	 [Job 247] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,530 nipype.workflow INFO:
# 	 [Job 248] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,532 nipype.workflow INFO:
# 	 [Job 249] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,534 nipype.workflow INFO:
# 	 [Job 250] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,535 nipype.workflow INFO:
# 	 [Job 251] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,537 nipype.workflow INFO:
# 	 [Job 252] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,539 nipype.workflow INFO:
# 	 [Job 253] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,541 nipype.workflow INFO:
# 	 [Job 254] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,543 nipype.workflow INFO:
# 	 [Job 255] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,544 nipype.workflow INFO:
# 	 [Job 256] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:33,546 nipype.workflow INFO:
# 	 [Job 257] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:33,548 nipype.workflow INFO:
# 	 [Job 258] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:33,550 nipype.workflow INFO:
# 	 [Job 259] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,114 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 537 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:35,319 nipype.workflow INFO:
# 	 [Job 260] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,322 nipype.workflow INFO:
# 	 [Job 261] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,324 nipype.workflow INFO:
# 	 [Job 262] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,325 nipype.workflow INFO:
# 	 [Job 263] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,327 nipype.workflow INFO:
# 	 [Job 264] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,329 nipype.workflow INFO:
# 	 [Job 265] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,331 nipype.workflow INFO:
# 	 [Job 266] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,333 nipype.workflow INFO:
# 	 [Job 267] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,335 nipype.workflow INFO:
# 	 [Job 268] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,336 nipype.workflow INFO:
# 	 [Job 269] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,338 nipype.workflow INFO:
# 	 [Job 270] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,340 nipype.workflow INFO:
# 	 [Job 271] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,342 nipype.workflow INFO:
# 	 [Job 272] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,344 nipype.workflow INFO:
# 	 [Job 273] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,345 nipype.workflow INFO:
# 	 [Job 274] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,347 nipype.workflow INFO:
# 	 [Job 275] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,349 nipype.workflow INFO:
# 	 [Job 276] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:35,351 nipype.workflow INFO:
# 	 [Job 277] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:35,352 nipype.workflow INFO:
# 	 [Job 278] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:35,354 nipype.workflow INFO:
# 	 [Job 279] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,116 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 543 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:37,321 nipype.workflow INFO:
# 	 [Job 280] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,324 nipype.workflow INFO:
# 	 [Job 281] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,326 nipype.workflow INFO:
# 	 [Job 282] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,328 nipype.workflow INFO:
# 	 [Job 283] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,329 nipype.workflow INFO:
# 	 [Job 284] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,331 nipype.workflow INFO:
# 	 [Job 285] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,333 nipype.workflow INFO:
# 	 [Job 286] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,335 nipype.workflow INFO:
# 	 [Job 287] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,337 nipype.workflow INFO:
# 	 [Job 288] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,338 nipype.workflow INFO:
# 	 [Job 289] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,340 nipype.workflow INFO:
# 	 [Job 290] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,342 nipype.workflow INFO:
# 	 [Job 291] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,344 nipype.workflow INFO:
# 	 [Job 292] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,346 nipype.workflow INFO:
# 	 [Job 293] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,347 nipype.workflow INFO:
# 	 [Job 294] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,349 nipype.workflow INFO:
# 	 [Job 295] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,351 nipype.workflow INFO:
# 	 [Job 296] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:37,353 nipype.workflow INFO:
# 	 [Job 297] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:37,354 nipype.workflow INFO:
# 	 [Job 298] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:37,356 nipype.workflow INFO:
# 	 [Job 299] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,118 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 546 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:39,324 nipype.workflow INFO:
# 	 [Job 300] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,326 nipype.workflow INFO:
# 	 [Job 301] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,328 nipype.workflow INFO:
# 	 [Job 302] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,330 nipype.workflow INFO:
# 	 [Job 303] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,332 nipype.workflow INFO:
# 	 [Job 304] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,334 nipype.workflow INFO:
# 	 [Job 305] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,336 nipype.workflow INFO:
# 	 [Job 306] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,338 nipype.workflow INFO:
# 	 [Job 307] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,339 nipype.workflow INFO:
# 	 [Job 308] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,341 nipype.workflow INFO:
# 	 [Job 309] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,343 nipype.workflow INFO:
# 	 [Job 310] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,345 nipype.workflow INFO:
# 	 [Job 311] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,347 nipype.workflow INFO:
# 	 [Job 312] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,348 nipype.workflow INFO:
# 	 [Job 313] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,350 nipype.workflow INFO:
# 	 [Job 314] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,352 nipype.workflow INFO:
# 	 [Job 315] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,354 nipype.workflow INFO:
# 	 [Job 316] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:39,356 nipype.workflow INFO:
# 	 [Job 317] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:39,357 nipype.workflow INFO:
# 	 [Job 318] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:39,359 nipype.workflow INFO:
# 	 [Job 319] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,325 nipype.workflow INFO:
# 	 [Job 320] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,328 nipype.workflow INFO:
# 	 [Job 321] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,330 nipype.workflow INFO:
# 	 [Job 322] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,331 nipype.workflow INFO:
# 	 [Job 323] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,333 nipype.workflow INFO:
# 	 [Job 324] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,335 nipype.workflow INFO:
# 	 [Job 325] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,337 nipype.workflow INFO:
# 	 [Job 326] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,339 nipype.workflow INFO:
# 	 [Job 327] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,340 nipype.workflow INFO:
# 	 [Job 328] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,342 nipype.workflow INFO:
# 	 [Job 329] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,344 nipype.workflow INFO:
# 	 [Job 330] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,346 nipype.workflow INFO:
# 	 [Job 331] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,348 nipype.workflow INFO:
# 	 [Job 332] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,349 nipype.workflow INFO:
# 	 [Job 333] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,351 nipype.workflow INFO:
# 	 [Job 334] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,353 nipype.workflow INFO:
# 	 [Job 335] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,355 nipype.workflow INFO:
# 	 [Job 336] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:41,356 nipype.workflow INFO:
# 	 [Job 337] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:41,358 nipype.workflow INFO:
# 	 [Job 338] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:41,360 nipype.workflow INFO:
# 	 [Job 339] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,326 nipype.workflow INFO:
# 	 [Job 340] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,329 nipype.workflow INFO:
# 	 [Job 341] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,331 nipype.workflow INFO:
# 	 [Job 342] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,332 nipype.workflow INFO:
# 	 [Job 343] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,334 nipype.workflow INFO:
# 	 [Job 344] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,336 nipype.workflow INFO:
# 	 [Job 345] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,338 nipype.workflow INFO:
# 	 [Job 346] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,340 nipype.workflow INFO:
# 	 [Job 347] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,342 nipype.workflow INFO:
# 	 [Job 348] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,343 nipype.workflow INFO:
# 	 [Job 349] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,345 nipype.workflow INFO:
# 	 [Job 350] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,347 nipype.workflow INFO:
# 	 [Job 351] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,349 nipype.workflow INFO:
# 	 [Job 352] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,351 nipype.workflow INFO:
# 	 [Job 353] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,353 nipype.workflow INFO:
# 	 [Job 354] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,354 nipype.workflow INFO:
# 	 [Job 355] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,356 nipype.workflow INFO:
# 	 [Job 356] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:43,358 nipype.workflow INFO:
# 	 [Job 357] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:43,360 nipype.workflow INFO:
# 	 [Job 358] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:43,362 nipype.workflow INFO:
# 	 [Job 359] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,323 nipype.workflow INFO:
# 	 [Job 360] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,326 nipype.workflow INFO:
# 	 [Job 361] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,328 nipype.workflow INFO:
# 	 [Job 362] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,330 nipype.workflow INFO:
# 	 [Job 363] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,332 nipype.workflow INFO:
# 	 [Job 364] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,334 nipype.workflow INFO:
# 	 [Job 365] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,335 nipype.workflow INFO:
# 	 [Job 366] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,337 nipype.workflow INFO:
# 	 [Job 367] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,339 nipype.workflow INFO:
# 	 [Job 368] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,341 nipype.workflow INFO:
# 	 [Job 369] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,343 nipype.workflow INFO:
# 	 [Job 370] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,345 nipype.workflow INFO:
# 	 [Job 371] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,347 nipype.workflow INFO:
# 	 [Job 372] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,348 nipype.workflow INFO:
# 	 [Job 373] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,350 nipype.workflow INFO:
# 	 [Job 374] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,352 nipype.workflow INFO:
# 	 [Job 375] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,354 nipype.workflow INFO:
# 	 [Job 376] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:45,356 nipype.workflow INFO:
# 	 [Job 377] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:45,358 nipype.workflow INFO:
# 	 [Job 378] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:45,360 nipype.workflow INFO:
# 	 [Job 379] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,125 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 545 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:47,331 nipype.workflow INFO:
# 	 [Job 380] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,334 nipype.workflow INFO:
# 	 [Job 381] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,335 nipype.workflow INFO:
# 	 [Job 382] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,337 nipype.workflow INFO:
# 	 [Job 383] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,339 nipype.workflow INFO:
# 	 [Job 384] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,341 nipype.workflow INFO:
# 	 [Job 385] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,342 nipype.workflow INFO:
# 	 [Job 386] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,344 nipype.workflow INFO:
# 	 [Job 387] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,346 nipype.workflow INFO:
# 	 [Job 388] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,347 nipype.workflow INFO:
# 	 [Job 389] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,349 nipype.workflow INFO:
# 	 [Job 390] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,351 nipype.workflow INFO:
# 	 [Job 391] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,352 nipype.workflow INFO:
# 	 [Job 392] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,354 nipype.workflow INFO:
# 	 [Job 393] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,356 nipype.workflow INFO:
# 	 [Job 394] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,357 nipype.workflow INFO:
# 	 [Job 395] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,359 nipype.workflow INFO:
# 	 [Job 396] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:47,361 nipype.workflow INFO:
# 	 [Job 397] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:47,362 nipype.workflow INFO:
# 	 [Job 398] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:47,364 nipype.workflow INFO:
# 	 [Job 399] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,127 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 550 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:49,329 nipype.workflow INFO:
# 	 [Job 400] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,332 nipype.workflow INFO:
# 	 [Job 401] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,334 nipype.workflow INFO:
# 	 [Job 402] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,335 nipype.workflow INFO:
# 	 [Job 403] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,337 nipype.workflow INFO:
# 	 [Job 404] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,339 nipype.workflow INFO:
# 	 [Job 405] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,340 nipype.workflow INFO:
# 	 [Job 406] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,342 nipype.workflow INFO:
# 	 [Job 407] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,344 nipype.workflow INFO:
# 	 [Job 408] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,346 nipype.workflow INFO:
# 	 [Job 409] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,347 nipype.workflow INFO:
# 	 [Job 410] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,349 nipype.workflow INFO:
# 	 [Job 411] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,351 nipype.workflow INFO:
# 	 [Job 412] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,352 nipype.workflow INFO:
# 	 [Job 413] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,354 nipype.workflow INFO:
# 	 [Job 414] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,356 nipype.workflow INFO:
# 	 [Job 415] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,357 nipype.workflow INFO:
# 	 [Job 416] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:49,359 nipype.workflow INFO:
# 	 [Job 417] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:49,360 nipype.workflow INFO:
# 	 [Job 418] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:49,362 nipype.workflow INFO:
# 	 [Job 419] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,128 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 555 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:51,329 nipype.workflow INFO:
# 	 [Job 420] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,331 nipype.workflow INFO:
# 	 [Job 421] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,333 nipype.workflow INFO:
# 	 [Job 422] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,335 nipype.workflow INFO:
# 	 [Job 423] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,337 nipype.workflow INFO:
# 	 [Job 424] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,339 nipype.workflow INFO:
# 	 [Job 425] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,340 nipype.workflow INFO:
# 	 [Job 426] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,342 nipype.workflow INFO:
# 	 [Job 427] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,344 nipype.workflow INFO:
# 	 [Job 428] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,346 nipype.workflow INFO:
# 	 [Job 429] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,348 nipype.workflow INFO:
# 	 [Job 430] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,349 nipype.workflow INFO:
# 	 [Job 431] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,351 nipype.workflow INFO:
# 	 [Job 432] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,353 nipype.workflow INFO:
# 	 [Job 433] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,355 nipype.workflow INFO:
# 	 [Job 434] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,356 nipype.workflow INFO:
# 	 [Job 435] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,358 nipype.workflow INFO:
# 	 [Job 436] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:51,360 nipype.workflow INFO:
# 	 [Job 437] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:51,362 nipype.workflow INFO:
# 	 [Job 438] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:51,363 nipype.workflow INFO:
# 	 [Job 439] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,130 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 552 jobs ready. Free memory (GB): 200.00/200.00, Free processors: 20/20.
# 240713-13:40:53,331 nipype.workflow INFO:
# 	 [Job 440] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,333 nipype.workflow INFO:
# 	 [Job 441] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,335 nipype.workflow INFO:
# 	 [Job 442] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,338 nipype.workflow INFO:
# 	 [Job 443] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,344 nipype.workflow INFO:
# 	 [Job 444] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,346 nipype.workflow INFO:
# 	 [Job 445] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,348 nipype.workflow INFO:
# 	 [Job 446] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,350 nipype.workflow INFO:
# 	 [Job 447] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,351 nipype.workflow INFO:
# 	 [Job 448] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,353 nipype.workflow INFO:
# 	 [Job 449] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,355 nipype.workflow INFO:
# 	 [Job 450] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,357 nipype.workflow INFO:
# 	 [Job 451] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,359 nipype.workflow INFO:
# 	 [Job 452] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,360 nipype.workflow INFO:
# 	 [Job 453] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,362 nipype.workflow INFO:
# 	 [Job 454] Cached (feat_level12_sst_roi.tr_getter).
# 240713-13:40:53,364 nipype.workflow INFO:
# 	 [Job 455] Cached (feat_level12_sst_roi.run_info_getter).
# 240713-13:40:53,366 nipype.workflow INFO:
# 	 [Job 456] Cached (feat_level12_sst_roi.task_getter).
# 240713-13:40:53,368 nipype.workflow INFO:
# ...
# 240713-13:46:38,876 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo4/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-varcope.nii.gz
# 240713-13:46:38,878 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo2/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-zstat.nii.gz
# 240713-13:46:38,880 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo5/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-varcope.nii.gz
# 240713-13:46:38,881 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo3/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-zstat.nii.gz
# 240713-13:46:38,883 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo0/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-tdof_t.nii.gz
# 240713-13:46:38,885 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo4/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-zstat.nii.gz
# 240713-13:46:38,887 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo1/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-tdof_t.nii.gz
# 240713-13:46:38,889 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_zstats/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo5/zstat1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-zstat.nii.gz
# 240713-13:46:38,891 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo2/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-tdof_t.nii.gz
# 240713-13:46:38,893 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo0/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-cope.nii.gz
# 240713-13:46:38,895 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo3/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-tdof_t.nii.gz
# 240713-13:46:38,897 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo1/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-cope.nii.gz
# 240713-13:46:38,899 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo4/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-tdof_t.nii.gz
# 240713-13:46:38,901 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo2/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-cope.nii.gz
# 240713-13:46:38,903 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10523_model_n_0_space_MNI152NLin2009cAsym/_flameo5/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10523/func/model-0/sub-10523_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-tdof_t.nii.gz
# 240713-13:46:38,904 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.139631s.
# 240713-13:46:38,905 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo3/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-cope.nii.gz
# 240713-13:46:38,908 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo4/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-cope.nii.gz
# 240713-13:46:38,912 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_copes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo5/cope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-cope.nii.gz
# 240713-13:46:38,916 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo0/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-varcope.nii.gz
# 240713-13:46:38,920 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo1/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-varcope.nii.gz
# 240713-13:46:38,924 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo2/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-varcope.nii.gz
# 240713-13:46:38,927 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo3/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-varcope.nii.gz
# 240713-13:46:38,931 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo4/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-varcope.nii.gz
# 240713-13:46:38,935 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_varcopes/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo5/varcope1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-varcope.nii.gz
# 240713-13:46:38,939 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo0/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-0_desc-tdof_t.nii.gz
# 240713-13:46:38,943 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo1/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-1_desc-tdof_t.nii.gz
# 240713-13:46:38,947 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo2/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-2_desc-tdof_t.nii.gz
# 240713-13:46:38,951 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo3/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-3_desc-tdof_t.nii.gz
# 240713-13:46:38,955 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo4/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-4_desc-tdof_t.nii.gz
# 240713-13:46:38,959 nipype.interface INFO:
# 	 sub: /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/mni/level2_tdof_ts/_ds_sub_openfmri_3T-10524_model_n_0_space_MNI152NLin2009cAsym/_flameo5/tdof_t1.nii.gz -> /home/scotti/projects/3t_7t_sst_comparison/derivatives/glm_feat_sst_roi/subject_level_model/openfmri_3T/sub-10524/func/model-0/sub-10524_task-sst_space-MNI152NLin2009cAsym_model-0_contrast-5_desc-tdof_t.nii.gz
# 240713-13:46:38,960 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.123942s.
# 240713-13:46:39,92 nipype.workflow INFO:
# 	 [Job 2548] Completed (feat_level12_sst_roi.datasink).
# 240713-13:46:39,94 nipype.workflow INFO:
# 	 [Job 2549] Completed (feat_level12_sst_roi.datasink).
# 240713-13:46:39,95 nipype.workflow INFO:
# 	 [Job 2378] Completed (feat_level12_sst_roi.flameo).
# 240713-13:46:39,96 nipype.workflow INFO:
# 	 [Job 2379] Completed (feat_level12_sst_roi.flameo).
# 240713-13:46:39,97 nipype.workflow INFO:
# 	 [Job 2380] Completed (feat_level12_sst_roi.flameo).
# 240713-13:46:39,98 nipype.workflow INFO:
# 	 [Job 2550] Completed (feat_level12_sst_roi.datasink).
# 240713-13:46:39,99 nipype.workflow INFO:
# 	 [Job 4422] Completed (_flameo0).
# 240713-13:46:39,100 nipype.workflow INFO:
# 	 [Job 4423] Completed (_flameo1).
# 240713-13:46:39,100 nipype.workflow INFO:
# 	 [Job 4424] Completed (_flameo2).
# 240713-13:46:39,100 nipype.workflow INFO:
# 	 [Job 4425] Completed (_flameo3).
# 240713-13:46:39,101 nipype.workflow INFO:
# 	 [Job 4426] Completed (_flameo4).
# 240713-13:46:39,101 nipype.workflow INFO:
# 	 [Job 4427] Completed (_flameo5).
# 240713-13:46:39,102 nipype.workflow INFO:
# 	 [Job 4428] Completed (_flameo0).
# 240713-13:46:39,102 nipype.workflow INFO:
# 	 [Job 4429] Completed (_flameo1).
# 240713-13:46:39,102 nipype.workflow INFO:
# 	 [Job 4430] Completed (_flameo2).
# 240713-13:46:39,103 nipype.workflow INFO:
# 	 [Job 4431] Completed (_flameo3).
# 240713-13:46:39,103 nipype.workflow INFO:
# 	 [Job 4432] Completed (_flameo4).
# 240713-13:46:39,104 nipype.workflow INFO:
# 	 [Job 4433] Completed (_flameo5).
# 240713-13:46:39,104 nipype.workflow INFO:
# 	 [Job 4434] Completed (_flameo0).
# 240713-13:46:39,110 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 511 jobs ready. Free memory (GB): 199.80/200.00, Free processors: 19/20.
#                      Currently running:
#                        * feat_level12_sst_roi.datasink

# %%
# !jupyter nbconvert --to script 09a_GLM_FEAT-ROI-ALL.ipynb
# Out:
# [NbConvertApp] Converting notebook 09a_GLM_FEAT-ROI-ALL.ipynb to script
# [NbConvertApp] Writing 16588 bytes to 09a_GLM_FEAT-ROI-ALL.py
