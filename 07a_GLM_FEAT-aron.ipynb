# %% [markdown]
# # FSL FEAT nipype

# %%
import os
import glob

import nipype
import nipype.interfaces.io as nio
import nipype.interfaces.fsl as fsl
import nipype.interfaces.ants as ants
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.algorithms.modelgen as model
# Out:
# 230202-16:34:06,683 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.7.0

# %% [markdown]
# ## pipeline setup

# %%
# Which dataset are we looking at?
# this_dataset = 'Leipzig_7T_SM'
# this_dataset = 'Leipzig_7T_GdH'
# this_dataset = 'NTNU_7T_SJSI'
this_dataset = 'aron_3T'

# %%
# general set-up
base_dir = '/home/scotti/projects/3t_7t_sst_comparison'
work_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders')
smooth_hp_dir = os.path.join(base_dir, 'derivatives', 'susan_smoothed_hp_func', this_dataset)

hpcutoff = 10000.   # in seconds
model_n = [0]
spaces = ['T1w']   # shouldn't touch this but just in case we _do_ want to go back to MNI....

if this_dataset == 'Leipzig_7T_SM':
    smoothing_fwhm = ['1p6']
    t_r = 3.0
    numsubs = 18
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(smooth_hp_dir, 'sub-*/'))]
    task = 'stop'
elif this_dataset == 'Leipzig_7T_GdH':
    smoothing_fwhm = ['1p5']
    t_r = 2.0
    numsubs = 20
    subject_ids = [x.split('/')[-1].split('-')[-1] for x in glob.glob(os.path.join(smooth_hp_dir, 'sub-*T'))]
    task = 'stop'
elif this_dataset == 'aron_3T':
    smoothing_fwhm = ['5p0']#['3p125']
    t_r = 2.0
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in glob.glob(os.path.join(smooth_hp_dir, 'sub-*/'))]
    numsubs = len(subject_ids)
    task = 'stopsignal'
    
# make sure all files required are found correctly    
smooths_ = glob.glob(os.path.join(base_dir, 'derivatives', 'susan_smoothed_hp_func', this_dataset,
                                        'sub-*', 'func',  f'sub-*_task-{task}_run-*_space-*_fwhm-{smoothing_fwhm[0]}_tempfilt.nii.gz'))
masks_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                              'sub-*', 'func', f'sub-*_task-{task}_run-*_space-*_desc-brain_mask.nii.gz'))
comp_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                    'sub-*', 'anat', 'sub-*_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'))
xfm_ = glob.glob(os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                              'sub-*', 'func',  f'sub-*_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'))
events_ = glob.glob(os.path.join(base_dir, f'derivatives/event_files/{this_dataset}/sub-*/func/sub-*run-*_events.tsv'))
    
template_brain = os.path.join(base_dir,'sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')

# %%
print(f"""
this dataset : {this_dataset}
smoothing_fwhm : {smoothing_fwhm}
tr : {t_r}
number of subjects : {numsubs}
subject ids : {subject_ids}
smooth_hp_dir : {smooth_hp_dir}
model ns : {model_n}
no. smooths : {len(smooths_)}
no. masks : {len(masks_)}
no. comps : {len(comp_)}
no. xfms : {len(xfm_)}
no.events : {len(events_)}

""")
# Out:
# this dataset : aron_3T
# smoothing_fwhm : ['5p0']
# tr : 2.0
# number of subjects : 14
# subject ids : ['15', '02', '14', '13', '10', '12', '05', '11', '06', '04', '01', '03', '07', '09']
# smooth_hp_dir : /home/scotti/projects/3t_7t_sst_comparison/derivatives/susan_smoothed_hp_func/aron_3T
# model ns : [0]
# no. smooths : 40
# no. masks : 40
# no. comps : 14
# no. xfms : 40
# no.events : 40

# %% [markdown]
# # first & second level models

# %%
def get_session_info(subject_id, run, task='stop', this_dataset='Leipzig_7T_SM', space='T1w', shift=-1.38/2, model_n=0,
                    root_dir='/home/scotti/projects/3t_7t_sst_comparison', include_physio=True):
    # other space: MNI152NLin2009cAsym
    import pandas as pd
    import numpy as np
    import os
    from nipype.interfaces.base import Bunch
            
    ### files ###
    sub = subject_id
    event_fn = f'{root_dir}/derivatives/event_files/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_events.tsv'
#         func_fn = f'{root_dir}/derivatives/fmriprep/fmriprep/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_space-{space}_desc-preproc_bold.nii.gz'
    confounds_fn = f'{root_dir}/derivatives/fmriprep/{this_dataset}/fmriprep/fmriprep/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.tsv'

    events = pd.read_csv(event_fn, sep='\t', index_col=None)
    events['duration'] = 0.001  # stick functions
    if model_n == 0:
        events = events.loc[events.trial_type.isin(['ss', 'fs', 'go'])]
    elif model_n == 1:
        events = events.loc[events.trial_type.isin(['response_left', 'response_right'])]
    events = events[['onset', 'trial_type', 'duration']]

    # slice time correction, nb: shift should be a negative number for STC
    events['onset'] += shift  

    ### confounds ###
    confounds = pd.read_csv(confounds_fn, sep='\t')
#        cosine_cols = [x for x in confounds.columns if 'cos' in x]
    include_confounds = ['trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z', 'dvars', 'framewise_displacement'] #+ cosine_cols
    confounds = confounds[include_confounds].fillna(method='bfill')

    # get retroicor
    if include_physio:
#         retroicor_fn = f'{root_dir}/derivatives/retroicor/sub-{sub}/ses-{ses}/func/sub-{sub}_ses-{ses}_task-{task}_run-{run}_desc-retroicor_regressors.tsv'
#         if not os.path.exists(retroicor_fn):
        ## take first 20 aCompCor components
        print("No retroicor found, including 20 a_comp_cor components")
        a_comp_cor = pd.read_csv(confounds_fn, sep='\t')[['a_comp_cor_' + str(x).zfill(2) for x in range(20)]]
        confounds = pd.concat([confounds, a_comp_cor], axis=1)
#         else:
#             retroicor = pd.read_csv(retroicor_fn, sep='\t', header=None).iloc[:,:20]  ## 20 components in total
#             retroicor.columns = ['cardiac_' + str(x) for x in range(6)] + ['respiratory_' + str(x) for x in range(8)] + ['respiratoryxcardiac_' + str(x) for x in range(4)] + ['HRV', 'RVT']
#             confounds = pd.concat([confounds, retroicor], axis=1)

    # save the confounds that we actually include in the GLM to csv, no header or index
    confounds_fn = f'{root_dir}/derivatives/confounds/{this_dataset}/sub-{sub}/func/sub-{sub}_task-{task}_run-{run}_desc-confounds_timeseries.txt'
    os.makedirs(os.path.dirname(confounds_fn), exist_ok=True)
    confounds.to_csv(confounds_fn, sep='\t', header=False, index=False)

    ### Make bunch ###
    if model_n == 0:
        conditions=['fs',
                    'ss',
                    'go']

    elif model_n ==1:
        conditions = [
                     'response_left',
                     'response_right'
                     ]

    onsets = [events.loc[events.trial_type==trial_type,'onset'].tolist() for trial_type in conditions]
    durations = [events.loc[events.trial_type==trial_type,'duration'].tolist() for trial_type in conditions]
    amplitudes = [[1] * events.loc[events.trial_type==trial_type,'onset'].shape[0] for trial_type in conditions]
#             amplitudes = [events.loc[events.trial_type==trial_type,'modulation'].tolist() for trial_type in conditions]

    info = Bunch(conditions=conditions,
                 onsets=onsets,
                 durations=durations,
                 amplitudes=amplitudes)
#         print(info)
    
    # always return info and the confounds_fn
    return info, confounds_fn #, contrasts[0]

if model_n == [0]:
    contrasts = [('fs', 'T', ['fs'], [1.0]),
                 ('ss', 'T', ['ss'], [1.0]),
                 ('go', 'T', ['go'], [1.0]),
                 ('fs-go', 'T', ['fs', 'go'], [1, -1]),
                 ('fs-ss', 'T', ['fs', 'ss'], [1, -1]),
                 ('ss-go', 'T', ['ss', 'go'], [1, -1])
                 ]
    
elif model_n == [1]:
    contrasts = [('response_left', 'T', ['response_left'], [1.0]),
                 ('response_right', 'T', ['response_right'], [1.0]),
                 ('left-right', 'T', ['response_left','response_right'], [1,-1])
                 ]

# %%
def get_runs_per_sub(subject_id):
    # here we can add the runs per subject if some subject miss a run or two
    if not subject_id in ['11','12']:
        runs = [1,2,3]
    else:
        runs = [1,2]
    
    return runs

# %%
workflow = pe.Workflow(name='feat_level12_sst_hp')
workflow.base_dir = os.path.join(base_dir, 'processing', 'nipype_workflow_folders', this_dataset)
workflow.config = {"execution": {"crashdump_dir":os.path.join(base_dir, 'processing', 'crashdumps')}}

# identity
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'space', 'model_n', 'smoothing_fwhm']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('space', spaces),
                      ('model_n', model_n),
                      ('smoothing_fwhm', smoothing_fwhm)]

# selector
# if running only one run, copy the mask from run 1 to run 2, 'mask' variable below needs a list, it will crash if only one is found
#(terrible way to get around this.. fix at some point.. lazy..)
templates = {'smoothed_funcs': os.path.join(base_dir, 'derivatives', 'susan_smoothed_hp_func', this_dataset,
                                            'sub-{subject_id}', 'func',  
                                            f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}*_fwhm-{{smoothing_fwhm}}_tempfilt.nii.gz'),
             'mask': os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_space-{{space}}_desc-brain_mask.nii.gz'),
             'composite':  os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                        'sub-{subject_id}', 'anat', 
                                        'sub-{subject_id}_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'),
             'xfm': os.path.join(base_dir, 'derivatives', 'fmriprep', this_dataset, 'fmriprep', 'fmriprep',
                                  'sub-{subject_id}', 'func', 
                                  f'sub-{{subject_id}}_task-{task}_run-*_from-scanner_to-T1w_mode-image_xfm.txt'),}
selector = pe.Node(nio.SelectFiles(templates), name='selector')

workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'space', selector, 'space')
workflow.connect(identity, 'smoothing_fwhm', selector, 'smoothing_fwhm')

# get run info per sub
run_info_getter = pe.Node(util.Function(function=get_runs_per_sub,
                                        input_names=['subject_id'],
                                        output_names=['runs']), name='run_info_getter')
workflow.connect(identity, 'subject_id', run_info_getter, 'subject_id')

# session info getter
session_info_getter = pe.MapNode(util.Function(function=get_session_info,
                                     input_names=['subject_id', 'run', 'task', 'this_dataset', 'space', 'shift', 'model_n'],
                                     output_names=['session_info', 'confounds']),
                                 iterfield=['run'],
                                 name='session_info_getter')
session_info_getter.inputs.task=task
session_info_getter.inputs.this_dataset=this_dataset
session_info_getter.inputs.space='T1w'
session_info_getter.inputs.shift = -t_r/2

workflow.connect(identity, 'subject_id', session_info_getter, 'subject_id')
workflow.connect(run_info_getter, 'runs', session_info_getter, 'run')
workflow.connect(identity, 'model_n', session_info_getter, 'model_n')


# model setup
specifymodel = pe.Node(model.SpecifyModel(), name='specifymodel1')
specifymodel.inputs.input_units = 'secs'
specifymodel.inputs.time_repetition = t_r
specifymodel.inputs.high_pass_filter_cutoff = hpcutoff

workflow.connect(session_info_getter, 'session_info', specifymodel, 'subject_info')
## old flow (with cosines): immediately connect to specifymodel
workflow.connect(selector, 'smoothed_funcs', specifymodel, 'functional_runs')

# Level 1 design
level1design = pe.Node(interface=fsl.Level1Design(), name="level1design")
level1design.inputs.interscan_interval = t_r
level1design.inputs.bases = {'dgamma': {'derivs': True}}
level1design.inputs.contrasts = contrasts
level1design.inputs.model_serial_correlations = True

workflow.connect(specifymodel, 'session_info', level1design, 'session_info')
# workflow.connect(session_info_getter, 'contrasts', level1design, 'contrasts')

# FEAT model
modelgen = pe.MapNode(interface=fsl.FEATModel(), iterfield=['ev_files', 'fsf_file', 'args'], name='modelgen')

workflow.connect(level1design, 'ev_files', modelgen, 'ev_files')
workflow.connect(level1design, 'fsf_files', modelgen, 'fsf_file')
workflow.connect(session_info_getter, 'confounds', modelgen, 'args')   # add confounds here


# FILM GLS
iterfield = ['design_file', 'in_file', 'tcon_file']
modelestimate = pe.MapNode(interface=fsl.FILMGLS(smooth_autocorr=True,
                                                 mask_size = 5,
                                                 threshold = 1000),  # 
                          name='modelestimate',
                          iterfield=iterfield,
                          mem_gb=10)

# ## old flow (with cosines): immediately connect to modelestimate
workflow.connect(selector, 'smoothed_funcs', modelestimate, 'in_file')
# # new flow: connect high-passed data
# workflow.connect(highpass, 'out_file', modelestimate, 'in_file')


workflow.connect(modelgen, 'design_file', modelestimate, 'design_file')
workflow.connect(modelgen, 'con_file', modelestimate, 'tcon_file')


#### Fixed effects
# merge copes, varcopes
copemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.MapNode(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskemerge = pe.MapNode(interface=fsl.Merge(dimension='t'),
                       iterfield=['in_files'],
                       name="maskemerge")

def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i,[])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles

workflow.connect(modelestimate, ('copes',sort_copes), copemerge, 'in_files')
workflow.connect(modelestimate, ('varcopes',sort_copes), varcopemerge, 'in_files')


level2model = pe.Node(interface=fsl.L2Model(), name='l2model')
def num_copes(files):
    return len(files)
workflow.connect(modelestimate, ('copes',num_copes), level2model, 'num_copes')


pickfirst = lambda x: x[0]
flameo = pe.MapNode(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="flameo",
    iterfield=['cope_file', 'var_cope_file'])

workflow.connect([
    (selector, flameo, [(('mask', pickfirst), 'mask_file')]),
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level2model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

## Warp to MNI-space
def warp_files(copes, varcopes, zstats, tdofs, mat, template_brain):
    # stolen from https://dpaniukov.github.io/2016/07/14/three-level-analysis-with-fsl-and-ants-2.html
    import nipype.interfaces.ants as ants

    out_copes = []
    out_varcopes = []
    out_zstats = []
    out_tdofs = []
    
    warp = ants.ApplyTransforms()
    warp.inputs.input_image_type = 0
    warp.inputs.interpolation = 'Linear'
    warp.inputs.invert_transform_flags = [False] #,False]
    warp.inputs.reference_image = template_brain
    warp.inputs.transforms = mat

    if not isinstance(copes, list):
        copes = [copes]
        varcopes = [varcopes]
        zstats = [zstats]
        tdofs = [tdofs]
    
    for cope in copes:
        warp.inputs.input_image = cope
        res=warp.run()
        out_copes.append(str(res.outputs.output_image))

    for varcope in varcopes:
        warp.inputs.input_image = varcope
        res=warp.run()
        out_varcopes.append(str(res.outputs.output_image))
        
    for zstat in zstats:
        warp.inputs.input_image = zstat
        res=warp.run()
        out_zstats.append(str(res.outputs.output_image))
    
    for tdof in tdofs:
        warp.inputs.input_image = tdof
        res=warp.run()
        out_tdofs.append(str(res.outputs.output_image))

    return out_copes, out_varcopes, out_zstats, out_tdofs

warpfunc = pe.MapNode(util.Function(input_names=['copes', 'varcopes', 'zstats', 'tdofs', 'mat','template_brain'],
                               output_names=['out_copes', 'out_varcopes', 'out_zstats', 'out_tdofs'],
                               function=warp_files),
                               iterfield=['copes', 'varcopes', 'zstats', 'tdofs'],
                  name='warpfunc')

warpfunc.inputs.template_brain = template_brain
workflow.connect(flameo, 'copes', warpfunc, 'copes')
workflow.connect(flameo, 'var_copes', warpfunc, 'varcopes')
workflow.connect(flameo, 'zstats', warpfunc, 'zstats')
workflow.connect(flameo, 'tdof', warpfunc, 'tdofs')
workflow.connect(selector, 'composite', warpfunc, 'mat')

#### post-FE analyis
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')

workflow.connect(selector, ('mask', pickfirst), smoothestimate, 'mask_file')
workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

#
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
workflow.connect(selector, ('mask', pickfirst), get_volume, 'in_file')

# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])] 
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

def convert_volume(input):
    return int(input[1])

workflow.connect(get_volume, ('out_stat', convert_volume), grf_cluster, 'volume')
grf_cluster.inputs.out_threshold_file = True


## datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(base_dir, 'derivatives', 'glm_feat_hp_sct')

#_model_n_0_smoothing_fwhm_1p5_space_T1w_subject_id_002
substitutions = [(f't1w/level2_{stat_type}s/_model_n_{model_n_}_smoothing_fwhm_{fwhm}_space_T1w_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
                  f'{this_dataset}/sub-{sub}/func/fwhm-{fwhm}/model-{model_n_}/sub-{sub}_task-{task}_space-T1w_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for fwhm in smoothing_fwhm
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]


substitutions += [(f'mni/level2_{stat_type}s/_model_n_{model_n_}_smoothing_fwhm_{fwhm}_space_T1w_subject_id_{sub}/_warpfunc{contrast_n}/{stat_type}1_trans.nii.gz',
                   f'{this_dataset}/sub-{sub}/func/fwhm-{fwhm}/model-{model_n_}/sub-{sub}_task-{task}_space-MNI152NLin2009cAsym_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
                  for sub in subject_ids
                  for contrast_n in range(len(contrasts))
                  for model_n_ in model_n
                  for fwhm in smoothing_fwhm
                  for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
                  ]

ds.inputs.substitutions = substitutions


## cluster thresholds: leave for now, this is more of a third-level model thing anyway
# workflow.connect(grf_cluster, 'threshold_file', ds, 'grf_thresholded_zstats_file')
# workflow.connect(grf_cluster, 'locnalmax_txt_file', ds, 'grf_localmax_txt_file')

## T1w-space
workflow.connect(flameo, 'zstats', ds, 'subject_level_model.t1w.level2_zstats')
workflow.connect(flameo, 'copes', ds, 'subject_level_model.t1w.level2_copes')
workflow.connect(flameo, 'var_copes', ds, 'subject_level_model.t1w.level2_varcopes')
workflow.connect(flameo, 'tdof', ds, 'subject_level_model.t1w.level2_tdof_ts')

## MNI-space
workflow.connect(warpfunc, 'out_zstats', ds, 'subject_level_model.mni.level2_zstats')
workflow.connect(warpfunc, 'out_copes', ds, 'subject_level_model.mni.level2_copes')
workflow.connect(warpfunc, 'out_varcopes', ds, 'subject_level_model.mni.level2_varcopes')
workflow.connect(warpfunc, 'out_tdofs', ds, 'subject_level_model.mni.level2_tdof_ts')
# workflow.connect(flameo, 'tdof', ds, 'level2_tdof')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs':10, 'memory_gb': 100})
# Out:
# 220923-15:13:11,748 nipype.workflow INFO:
# 	 Workflow feat_level12_sst_hp settings: ['check', 'execution', 'logging', 'monitoring']
# 220923-15:13:12,286 nipype.workflow INFO:
# 	 Running in parallel.
# 220923-15:13:12,468 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:12,582 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/run_info_getter".
# 220923-15:13:12,581 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/selector".
# 220923-15:13:12,584 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/selector".
# 220923-15:13:12,585 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/run_info_getter".
# 220923-15:13:12,587 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/run_info_getter".
# 220923-15:13:12,589 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/run_info_getter".
# 220923-15:13:12,589 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/selector".
# 220923-15:13:12,587 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/selector".
# 220923-15:13:12,589 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/run_info_getter".
# 220923-15:13:12,594 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:12,594 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:12,597 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:12,598 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:12,597 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:12,596 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/selector".
# 220923-15:13:12,596 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:12,603 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002622s.
# 220923-15:13:12,605 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:12,605 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002665s.
# 220923-15:13:12,605 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:12,606 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.002603s.
# 220923-15:13:12,607 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000828s.
# 220923-15:13:12,606 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000786s.
# 220923-15:13:12,607 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:12,614 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.001282s.
# 220923-15:13:12,623 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:12,627 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.00087s.
# 220923-15:13:12,634 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.025238s.
# 220923-15:13:12,634 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.025498s.
# 220923-15:13:12,636 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.007821s.
# 220923-15:13:14,470 nipype.workflow INFO:
# 	 [Job 0] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:14,472 nipype.workflow INFO:
# 	 [Job 1] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:14,475 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:14,477 nipype.workflow INFO:
# 	 [Job 3] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:14,479 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:14,481 nipype.workflow INFO:
# 	 [Job 5] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:14,483 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:14,484 nipype.workflow INFO:
# 	 [Job 7] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:14,486 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:14,487 nipype.workflow INFO:
# 	 [Job 9] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:14,490 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:14,564 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_12/selector".
# 220923-15:13:14,566 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/selector".
# 220923-15:13:14,567 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_11/selector".
# 220923-15:13:14,568 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_06/selector".
# 220923-15:13:14,569 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_06/run_info_getter".
# 220923-15:13:14,567 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_11/run_info_getter".
# 220923-15:13:14,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_04/run_info_getter".
# 220923-15:13:14,565 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_12/run_info_getter".
# 220923-15:13:14,566 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/run_info_getter".
# 220923-15:13:14,574 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:14,576 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:14,576 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:14,581 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000539s.
# 220923-15:13:14,580 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:14,584 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002007s.
# 220923-15:13:14,581 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:14,583 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000525s.
# 220923-15:13:14,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_04/selector".
# 220923-15:13:14,584 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:14,584 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:14,590 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002086s.
# 220923-15:13:14,590 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000647s.
# 220923-15:13:14,584 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:14,593 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000427s.
# 220923-15:13:14,598 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000495s.
# 220923-15:13:14,599 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:14,587 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:14,611 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.004045s.
# 220923-15:13:14,611 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.020696s.
# 220923-15:13:14,605 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002067s.
# 220923-15:13:16,472 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:16,474 nipype.workflow INFO:
# 	 [Job 11] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:16,475 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:16,476 nipype.workflow INFO:
# 	 [Job 13] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:16,477 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:16,478 nipype.workflow INFO:
# 	 [Job 15] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:16,481 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:16,483 nipype.workflow INFO:
# 	 [Job 17] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:16,484 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:16,486 nipype.workflow INFO:
# 	 [Job 19] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:16,489 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 38 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:16,568 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_01/selector".
# 220923-15:13:16,570 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_01/run_info_getter".
# 220923-15:13:16,577 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:16,571 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_03/run_info_getter".
# 220923-15:13:16,571 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_03/selector".
# 220923-15:13:16,573 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/selector".
# 220923-15:13:16,575 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:16,577 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/run_info_getter".
# 220923-15:13:16,578 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:16,577 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:16,579 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.00195s.
# 220923-15:13:16,579 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.selector" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/selector".
# 220923-15:13:16,582 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/get_volume".
# 220923-15:13:16,581 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.run_info_getter" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/run_info_getter".
# 220923-15:13:16,582 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/get_volume".
# 220923-15:13:16,583 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:16,584 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000519s.
# 220923-15:13:16,586 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:16,591 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001822s.
# 220923-15:13:16,587 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 220923-15:13:16,593 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000447s.
# 220923-15:13:16,591 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002014s.
# 220923-15:13:16,597 nipype.workflow INFO:
# 	 [Node] Executing "run_info_getter" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:16,598 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.002339s.
# 220923-15:13:16,599 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000412s.
# 220923-15:13:16,600 nipype.workflow INFO:
# 	 [Node] Finished "run_info_getter", elapsed time 0.000604s.
# 220923-15:13:16,617 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:16,632 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:16,760 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.138388s.
# 220923-15:13:16,789 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.15172s.
# 220923-15:13:18,474 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:18,475 nipype.workflow INFO:
# 	 [Job 21] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:18,477 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:18,478 nipype.workflow INFO:
# 	 [Job 23] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:18,480 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:18,481 nipype.workflow INFO:
# 	 [Job 25] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:18,482 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level12_sst_hp.selector).
# 220923-15:13:18,483 nipype.workflow INFO:
# 	 [Job 27] Completed (feat_level12_sst_hp.run_info_getter).
# 220923-15:13:18,485 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:18,486 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:18,489 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 44 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:18,551 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/get_volume".
# 220923-15:13:18,554 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/get_volume".
# 220923-15:13:18,557 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_12/get_volume".
# 220923-15:13:18,555 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/get_volume".
# 220923-15:13:18,560 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/get_volume".
# 220923-15:13:18,560 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_11/get_volume".
# 220923-15:13:18,563 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_01/get_volume".
# 220923-15:13:18,557 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,565 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,562 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,560 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_06/get_volume".
# 220923-15:13:18,569 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,561 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_04/get_volume".
# 220923-15:13:18,572 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,581 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,573 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,587 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_03/get_volume".
# 220923-15:13:18,583 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,581 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,603 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:18,733 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.158418s.
# 220923-15:13:18,767 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.181359s.
# 220923-15:13:18,782 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.181411s.
# 220923-15:13:18,765 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.191493s.
# 220923-15:13:18,790 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.220639s.
# 220923-15:13:18,784 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.20352s.
# 220923-15:13:18,796 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.165948s.
# 220923-15:13:18,800 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.206063s.
# 220923-15:13:18,813 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.22178s.
# 220923-15:13:18,823 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.251155s.
# 220923-15:13:20,475 nipype.workflow INFO:
# 	 [Job 32] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,477 nipype.workflow INFO:
# 	 [Job 34] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,479 nipype.workflow INFO:
# 	 [Job 36] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,480 nipype.workflow INFO:
# 	 [Job 38] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,482 nipype.workflow INFO:
# 	 [Job 40] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,483 nipype.workflow INFO:
# 	 [Job 42] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,484 nipype.workflow INFO:
# 	 [Job 44] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,485 nipype.workflow INFO:
# 	 [Job 46] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,486 nipype.workflow INFO:
# 	 [Job 48] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,488 nipype.workflow INFO:
# 	 [Job 50] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:20,491 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:20,571 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/get_volume".
# 220923-15:13:20,572 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:20,571 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.get_volume" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/get_volume".
# 220923-15:13:20,574 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:20,574 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:20,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:20,580 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,583 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:20,582 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:20,579 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,581 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:20,586 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:20,590 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,587 nipype.workflow INFO:
# 	 [Node] Executing "get_volume" <nipype.interfaces.fsl.utils.ImageStats>
# 220923-15:13:20,583 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:20,614 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,616 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,618 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,616 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,614 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:20,756 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.162632s.
# 220923-15:13:20,882 nipype.workflow INFO:
# 	 [Node] Finished "get_volume", elapsed time 0.288501s.
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
#
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# 220923-15:13:21,126 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.542197s.
# 220923-15:13:21,125 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.503015s.
# 220923-15:13:21,128 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.506435s.
# 220923-15:13:21,129 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.503348s.
# 220923-15:13:21,125 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.507247s.
# 220923-15:13:21,134 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.530293s.
# 220923-15:13:21,130 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.540505s.
# 220923-15:13:21,147 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.504129s.
# 220923-15:13:22,478 nipype.workflow INFO:
# 	 [Job 52] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:22,480 nipype.workflow INFO:
# 	 [Job 54] Completed (feat_level12_sst_hp.get_volume).
# 220923-15:13:22,481 nipype.workflow INFO:
# 	 [Job 238] Completed (_session_info_getter0).
# 220923-15:13:22,482 nipype.workflow INFO:
# 	 [Job 239] Completed (_session_info_getter1).
# 220923-15:13:22,483 nipype.workflow INFO:
# 	 [Job 240] Completed (_session_info_getter2).
# 220923-15:13:22,484 nipype.workflow INFO:
# 	 [Job 241] Completed (_session_info_getter0).
# 220923-15:13:22,485 nipype.workflow INFO:
# 	 [Job 242] Completed (_session_info_getter1).
# 220923-15:13:22,486 nipype.workflow INFO:
# 	 [Job 243] Completed (_session_info_getter2).
# 220923-15:13:22,487 nipype.workflow INFO:
# 	 [Job 244] Completed (_session_info_getter0).
# 220923-15:13:22,488 nipype.workflow INFO:
# 	 [Job 245] Completed (_session_info_getter1).
# 220923-15:13:22,490 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:22,565 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:22,567 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:22,571 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 220923-15:13:22,571 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:22,572 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 220923-15:13:22,573 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:22,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:22,578 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 220923-15:13:22,580 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 220923-15:13:22,581 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:22,574 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:22,584 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,573 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:22,573 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:22,585 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:22,584 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:22,585 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:22,595 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,600 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,595 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,601 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,602 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,599 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,601 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 220923-15:13:22,613 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 220923-15:13:22,616 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:22,618 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 220923-15:13:22,605 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:22,619 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 220923-15:13:22,635 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 220923-15:13:22,646 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 220923-15:13:22,648 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:22,654 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 220923-15:13:22,656 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
#
# No retroicor found, including 20 a_comp_cor componentsNo retroicor found, including 20 a_comp_cor components
#
#
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# 220923-15:13:22,815 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.21297s.
# 220923-15:13:22,820 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.213472s.
# 220923-15:13:22,814 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.202278s.
# 220923-15:13:22,825 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.221158s.
# 220923-15:13:22,830 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter1", elapsed time 0.207863s.
# 220923-15:13:22,840 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.254257s.
# 220923-15:13:22,841 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter2", elapsed time 0.227996s.
# 220923-15:13:22,859 nipype.workflow INFO:
# 	 [Node] Finished "_session_info_getter0", elapsed time 0.249285s.
# 220923-15:13:24,478 nipype.workflow INFO:
# 	 [Job 29] Completed (feat_level12_sst_hp.session_info_getter).
# 220923-15:13:24,480 nipype.workflow INFO:
# 	 [Job 31] Completed (feat_level12_sst_hp.session_info_getter).
# 220923-15:13:24,482 nipype.workflow INFO:
# 	 [Job 246] Completed (_session_info_getter2).
# 220923-15:13:24,483 nipype.workflow INFO:
# 	 [Job 247] Completed (_session_info_getter0).
# 220923-15:13:24,485 nipype.workflow INFO:
# 	 [Job 248] Completed (_session_info_getter1).
# 220923-15:13:24,485 nipype.workflow INFO:
# 	 [Job 249] Completed (_session_info_getter2).
# 220923-15:13:24,486 nipype.workflow INFO:
# 	 [Job 250] Completed (_session_info_getter0).
# 220923-15:13:24,487 nipype.workflow INFO:
# 	 [Job 251] Completed (_session_info_getter1).
# 220923-15:13:24,488 nipype.workflow INFO:
# 	 [Job 252] Completed (_session_info_getter2).
# 220923-15:13:24,489 nipype.workflow INFO:
# 	 [Job 253] Completed (_session_info_getter0).
# 220923-15:13:24,491 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 29 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:13:24,567 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_15/specifymodel1".
# 220923-15:13:24,568 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level12_sst_hp.specifymodel1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_02/specifymodel1".
# 220923-15:13:24,569 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_12/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:24,574 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:24,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:24,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:24,580 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 220923-15:13:24,581 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_11/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:24,578 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:24,581 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:24,577 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter0".
# 220923-15:13:24,583 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:24,583 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 220923-15:13:24,585 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter2" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:24,586 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 220923-15:13:24,588 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:24,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_05/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:24,589 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 220923-15:13:24,591 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 220923-15:13:24,591 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter0" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:24,592 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:24,592 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 220923-15:13:24,596 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 220923-15:13:24,598 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 220923-15:13:24,597 nipype.workflow INFO:
# 	 [Node] Executing "_session_info_getter1" <nipype.interfaces.utility.wrappers.Function>
# 220923-15:13:24,601 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_13/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:24,605 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 220923-15:13:24,606 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 220923-15:13:24,613 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_10/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:24,618 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 220923-15:13:24,626 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter0" - collecting precomputed outputs
# 220923-15:13:24,627 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# 220923-15:13:24,633 nipype.workflow INFO:
# 	 [Node] "_session_info_getter0" found cached.
# 220923-15:13:24,636 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter1".
# 220923-15:13:24,647 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 220923-15:13:24,656 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.005769s.
# 220923-15:13:24,656 nipype.workflow INFO:
# 	 [Node] Executing "specifymodel1" <nipype.algorithms.modelgen.SpecifyModel>
# 220923-15:13:24,663 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter1" - collecting precomputed outputs
# 220923-15:13:24,669 nipype.workflow INFO:
# 	 [Node] "_session_info_getter1" found cached.
# 220923-15:13:24,672 nipype.workflow INFO:
# 	 [Node] Setting-up "_session_info_getter2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_14/session_info_getter/mapflow/_session_info_getter2".
# 220923-15:13:24,674 nipype.workflow INFO:
# 	 [Node] Finished "specifymodel1", elapsed time 0.012968s.
# 220923-15:13:24,674 nipype.workflow INFO:
# 	 [Node] Cached "_session_info_getter2" - collecting precomputed outputs
# 220923-15:13:24,681 nipype.workflow INFO:
# 	 [Node] "_session_info_getter2" found cached.
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# No retroicor found, including 20 a_comp_cor components
# ...
# 220923-15:24:51,285 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:51,268 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:51,271 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:51,286 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 220923-15:24:51,287 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 220923-15:24:51,290 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 220923-15:24:51,287 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:51,289 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:51,298 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:51,295 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 220923-15:24:51,302 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 220923-15:24:51,293 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:51,309 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 220923-15:24:51,311 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:51,314 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 220923-15:24:51,314 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 220923-15:24:51,323 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 220923-15:24:51,324 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 220923-15:24:51,326 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 220923-15:24:51,326 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 220923-15:24:51,331 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 220923-15:24:51,333 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 220923-15:24:51,335 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 220923-15:24:51,337 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 220923-15:24:51,330 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 220923-15:24:51,339 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 220923-15:24:51,339 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 220923-15:24:51,348 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 220923-15:24:51,351 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 220923-15:24:51,342 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 220923-15:24:51,356 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 220923-15:24:51,359 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 220923-15:24:51,364 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 220923-15:24:51,377 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_07/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 220923-15:24:51,410 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 220923-15:24:51,412 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 220923-15:24:51,461 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.171254s.
# 220923-15:24:51,462 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.182339s.
# 220923-15:24:51,456 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.15731s.
# 220923-15:24:51,481 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.191413s.
# 220923-15:24:51,487 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.2034s.
# 220923-15:24:51,492 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.214774s.
# 220923-15:24:51,509 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.2022s.
# 220923-15:24:51,544 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 0.245727s.
# 220923-15:24:53,143 nipype.workflow INFO:
# 	 [Job 233] Completed (feat_level12_sst_hp.grf_cluster).
# 220923-15:24:53,145 nipype.workflow INFO:
# 	 [Job 234] Completed (feat_level12_sst_hp.grf_cluster).
# 220923-15:24:53,147 nipype.workflow INFO:
# 	 [Job 934] Completed (_grf_cluster0).
# 220923-15:24:53,148 nipype.workflow INFO:
# 	 [Job 935] Completed (_grf_cluster1).
# 220923-15:24:53,149 nipype.workflow INFO:
# 	 [Job 936] Completed (_grf_cluster2).
# 220923-15:24:53,150 nipype.workflow INFO:
# 	 [Job 937] Completed (_grf_cluster3).
# 220923-15:24:53,151 nipype.workflow INFO:
# 	 [Job 938] Completed (_grf_cluster4).
# 220923-15:24:53,151 nipype.workflow INFO:
# 	 [Job 939] Completed (_grf_cluster5).
# 220923-15:24:53,152 nipype.workflow INFO:
# 	 [Job 940] Completed (_grf_cluster0).
# 220923-15:24:53,153 nipype.workflow INFO:
# 	 [Job 941] Completed (_grf_cluster1).
# 220923-15:24:53,156 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:24:53,248 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:53,249 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 220923-15:24:53,251 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 220923-15:24:53,250 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 220923-15:24:53,254 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster2" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:53,256 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster5" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:53,258 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster3" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:53,256 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 220923-15:24:53,264 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 220923-15:24:53,258 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster4" <nipype.interfaces.fsl.model.Cluster>
# 220923-15:24:53,266 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 220923-15:24:53,274 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 220923-15:24:53,280 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 220923-15:24:53,283 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 220923-15:24:53,285 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:53,290 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 220923-15:24:53,293 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 220923-15:24:53,301 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster3".
# 220923-15:24:53,309 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 220923-15:24:53,314 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 220923-15:24:53,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster4".
# 220923-15:24:53,322 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 220923-15:24:53,324 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 220923-15:24:53,329 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_2.3/grf_cluster/mapflow/_grf_cluster5".
# 220923-15:24:53,335 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 220923-15:24:53,339 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 220923-15:24:53,413 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster5", elapsed time 0.152319s.
# 220923-15:24:53,428 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster3", elapsed time 0.167292s.
# 220923-15:24:53,430 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster4", elapsed time 0.162355s.
# 220923-15:24:53,430 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster2", elapsed time 0.164812s.
# 220923-15:24:55,145 nipype.workflow INFO:
# 	 [Job 236] Completed (feat_level12_sst_hp.grf_cluster).
# 220923-15:24:55,147 nipype.workflow INFO:
# 	 [Job 942] Completed (_grf_cluster2).
# 220923-15:24:55,148 nipype.workflow INFO:
# 	 [Job 943] Completed (_grf_cluster3).
# 220923-15:24:55,150 nipype.workflow INFO:
# 	 [Job 944] Completed (_grf_cluster4).
# 220923-15:24:55,151 nipype.workflow INFO:
# 	 [Job 945] Completed (_grf_cluster5).
# 220923-15:24:55,154 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.
# 220923-15:24:55,242 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 220923-15:24:55,248 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 220923-15:24:55,251 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 220923-15:24:55,254 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 220923-15:24:55,257 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 220923-15:24:55,260 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 220923-15:24:55,263 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster2" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster2".
# 220923-15:24:55,318 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster2" - collecting precomputed outputs
# 220923-15:24:55,323 nipype.workflow INFO:
# 	 [Node] "_grf_cluster2" found cached.
# 220923-15:24:55,327 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster3" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster3".
# 220923-15:24:55,331 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster3" - collecting precomputed outputs
# 220923-15:24:55,333 nipype.workflow INFO:
# 	 [Node] "_grf_cluster3" found cached.
# 220923-15:24:55,336 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster4" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster4".
# 220923-15:24:55,365 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster4" - collecting precomputed outputs
# 220923-15:24:55,368 nipype.workflow INFO:
# 	 [Node] "_grf_cluster4" found cached.
# 220923-15:24:55,372 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster5" in "/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_5p0_space_T1w_subject_id_09/_threshold_3.1/grf_cluster/mapflow/_grf_cluster5".
# 220923-15:24:55,378 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster5" - collecting precomputed outputs
# 220923-15:24:55,380 nipype.workflow INFO:
# 	 [Node] "_grf_cluster5" found cached.
# 220923-15:24:57,147 nipype.workflow INFO:
# 	 [Job 237] Completed (feat_level12_sst_hp.grf_cluster).
# 220923-15:24:57,151 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 100.00/100.00, Free processors: 10/10.

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220920-095832-scotti-_modelgen0-589fd8c4-5612-47cf-b431-6183dc464cac.pklz')
res
# Out:
# {'node': _modelgen0,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen0.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/crashdumps/crash-20220725-201456-scotti-_modelgen2-853c3a8d-a5d2-434c-9c99-ac3b0735bd4a.pklz')
res
# Out:
# {'node': _modelgen2,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 521, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 639, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 750, in _run_command\n    raise NodeExecutionError(\n',
#   'nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _modelgen2.\n\nTraceback (most recent call last):\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 401, in run\n    outputs = self.aggregate_outputs(runtime)\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 430, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n  File "/home/scotti/.local/lib/python3.8/site-packages/nipype/interfaces/fsl/model.py", line 544, in _list_outputs\n    assert len(design_file) == 1, "No mat file generated by FEAT Model"\nAssertionError: No mat file generated by FEAT Model\n\n']}
# ERROR! Session/line number was not unique in database. History logging moved to new session 260

# %%
from nipype.utils.filemanip import loadpkl
res = loadpkl('/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/result_modelgen.pklz')
res

# %%
res.outputs
# Out:
# Bunch(con_file=['/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen0/run0.con',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.con',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen2/run2.con'],
#       design_cov=<undefined>,
#       design_file=['/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen0/run0.mat',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen1/run1.mat',
#        '/home/scotti/projects/3t_7t_sst_comparison/processing/nipype_workflow_folders/aron_3T/feat_level12_sst_hp/_model_n_0_smoothing_fwhm_3p125_space_T1w_subject_id_01/modelgen/mapflow/_modelgen2/run2.mat'],
#       design_image=<undefined>,
#       fcon_file=<undefined>)
